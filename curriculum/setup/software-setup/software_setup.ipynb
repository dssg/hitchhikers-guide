# %% [markdown]
# # Jupyter and  Python Package Tests
#
# Let's see if everything works, shall we!? :D
#
# Run the following following cells by either hitting the `run cell` button above (looks like a play button), or by the shortcut `shift` + `enter`.
#
# **If you installed all of these packages**, you'll see something like the following print out for each:
#
# `<module 'numpy' from '/Users/mollie/.pyenv/versions/dssg_2026/lib/python3.9/site-packages/numpy/__init__.py'>`.
#
# **If it is not installed**, you will get an error instead.

# %%
import numpy
numpy
# Out:
# <module 'numpy' from '/mnt/data/users/liliana/.pyenv/versions/dssg_2026/lib/python3.9/site-packages/numpy/__init__.py'>

# %%
import scipy
scipy
# Out:
# <module 'scipy' from '/mnt/data/users/liliana/.pyenv/versions/dssg_2026/lib/python3.9/site-packages/scipy/__init__.py'>

# %%
import pandas
pandas
# Out:
# <module 'pandas' from '/mnt/data/users/liliana/.pyenv/versions/dssg_2026/lib/python3.9/site-packages/pandas/__init__.py'>

# %%
import matplotlib
matplotlib
# Out:
# <module 'matplotlib' from '/mnt/data/users/liliana/.pyenv/versions/dssg_2026/lib/python3.9/site-packages/matplotlib/__init__.py'>

# %%
import seaborn
seaborn
# Out:
# <module 'seaborn' from '/mnt/data/users/liliana/.pyenv/versions/dssg_2026/lib/python3.9/site-packages/seaborn/__init__.py'>

# %%
import psycopg2
psycopg2
# Out:
# <module 'psycopg2' from '/mnt/data/users/liliana/.pyenv/versions/dssg_2026/lib/python3.9/site-packages/psycopg2/__init__.py'>

# %% [markdown]
# Congrats! You're all set up! :D
