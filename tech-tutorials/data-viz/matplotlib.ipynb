# %%
# use this directive to embed plots in the notebook
# %matplotlib inline

# import matplotlib
import matplotlib.pyplot as plt
import matplotlib

# use this to change the default style,
# use matplotlib.style.available to see
# available styles
matplotlib.style.use('fivethirtyeight')

# change the size of the plots
plt.rcParams['figure.figsize'] = (15, 5)

# we are using numpy just to generate some data
import numpy as np

# %% [markdown]
# ## Line plots

# %%
y = np.random.rand(100)
x = np.arange(100)

# %%
plt.plot(x, y)
plt.title('Title')

# %% [markdown]
# ## Bar plots
#
# Plotting bars using matplotlib is not straightforward, it requires us to specify the x, y coordinates for every bar!

# %%
left = np.arange(5)
height = np.random.rand(5)
yerr = np.random.rand(5)/5
width = 0.4

# %%
plt.bar(lefts, height, width, align='center', yerr=yerr)
# Out:
# <Container object of 5 artists>

# %% [markdown]
# ## Boxplot

# %%
x = np.random.rand(100, 4)

# %%
#we are assigning the result just to supress the matplotlib text output
bp = plt.boxplot(x)

# %% [markdown]
# ## Histogram

# %%
x = np.random.rand(100, 4) * 100

# %%
h = plt.hist(x)

# %% [markdown]
# ## Errorbar plot

# %%
y = np.random.normal(0,1,100)*10
x = np.arange(100)
yerr = np.random.rand(100)*10

# %%
err = plt.errorbar(x, y, yerr=yerr)
